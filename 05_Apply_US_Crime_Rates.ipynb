# %% [markdown]
# <a href="https://colab.research.google.com/github/Hainguyendangduc/PythonForDataAnalysis/blob/main/05_Apply_US_Crime_Rates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # United States - Crime Rates - 1960 - 2014

# %% [markdown]
# ### Introduction:
#
# This time you will create a data
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/US_Crime_Rates_1960_2014.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called crime.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/US_Crime_Rates_1960_2014.csv")

# %%
print(df)
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %% [markdown]
# ### Step 4. What is the type of the columns?

# %%
print(df.dtypes)
# Out:
# Year                  int64
# Population            int64
# Total                 int64
# Violent               int64
# Property              int64
# Murder                int64
# Forcible_Rape         int64
# Robbery               int64
# Aggravated_assault    int64
# Burglary              int64
# Larceny_Theft         int64
# Vehicle_Theft         int64
# dtype: object

# %% [markdown]
# ##### Have you noticed that the type of Year is int64. But pandas has a different type to work with Time Series. Let's see it now.
#
# ### Step 5. Convert the type of the column Year to datetime64

# %%
df['Year'] = pd.to_datetime(df['Year'])

# %% [markdown]
# ### Step 6. Set the Year column as the index of the dataframe

# %%
df1 = pd.DataFrame(df.iloc[:,1:].values,
                   index=df['Year'].values,
                   columns=df.columns[1:])
print(df1)
# Out:
#                                Population     Total  Violent  Property  \
# 1970-01-01 00:00:00.000001960   179323175   3384200   288460   3095700
# 1970-01-01 00:00:00.000001961   182992000   3488000   289390   3198600
# 1970-01-01 00:00:00.000001962   185771000   3752200   301510   3450700
# 1970-01-01 00:00:00.000001963   188483000   4109500   316970   3792500
# 1970-01-01 00:00:00.000001964   191141000   4564600   364220   4200400
# 1970-01-01 00:00:00.000001965   193526000   4739400   387390   4352000
# 1970-01-01 00:00:00.000001966   195576000   5223500   430180   4793300
# 1970-01-01 00:00:00.000001967   197457000   5903400   499930   5403500
# 1970-01-01 00:00:00.000001968   199399000   6720200   595010   6125200
# 1970-01-01 00:00:00.000001969   201385000   7410900   661870   6749000
# 1970-01-01 00:00:00.000001970   203235298   8098000   738820   7359200
# 1970-01-01 00:00:00.000001971   206212000   8588200   816500   7771700
# ...

# %% [markdown]
# ### Step 7. Delete the Total column

# %%
del df1['Total']
print(df1)
# Out:
#                                Population  Violent  Property  Murder  \
# 1970-01-01 00:00:00.000001960   179323175   288460   3095700    9110
# 1970-01-01 00:00:00.000001961   182992000   289390   3198600    8740
# 1970-01-01 00:00:00.000001962   185771000   301510   3450700    8530
# 1970-01-01 00:00:00.000001963   188483000   316970   3792500    8640
# 1970-01-01 00:00:00.000001964   191141000   364220   4200400    9360
# 1970-01-01 00:00:00.000001965   193526000   387390   4352000    9960
# 1970-01-01 00:00:00.000001966   195576000   430180   4793300   11040
# 1970-01-01 00:00:00.000001967   197457000   499930   5403500   12240
# 1970-01-01 00:00:00.000001968   199399000   595010   6125200   13800
# 1970-01-01 00:00:00.000001969   201385000   661870   6749000   14760
# 1970-01-01 00:00:00.000001970   203235298   738820   7359200   16000
# 1970-01-01 00:00:00.000001971   206212000   816500   7771700   17780
# 1970-01-01 00:00:00.000001972   208230000   834900   7413900   18670
# ...

# %% [markdown]
# ### Step 8. Group the year by decades and sum the values
#
# #### Pay attention to the Population column number, summing this column is a mistake

# %% [markdown]
# ### Step 9. What is the most dangerous decade to live in the US?
